# %%
import json

data_path = "/qumulo/shared_data/aofei_summer/data/LVLM/HuatuoGPT/60k_PubMedVision_InstructionTuning_VQA.json"
seg_data_path = "/qumulo/shared_data/aofei_summer/data/RegAlign/instruction_tuning_45k.json"
with open(data_path, "r") as f:
    data = json.load(f)
with open(seg_data_path, "r") as f:
    seg_data = json.load(f)

# %%
data[107]
# Out:
# {'image': ['images_all/pmc_310784_0.jpg'],
#  'conversations': [{'from': 'human',
#    'value': "Can you describe the significance of the structures marked by arrows in this electron micrograph and what might their presence indicate about the cell's functional state?"},
#   {'from': 'gpt',
#    'value': "The structures marked by the arrows in the electron micrograph are likely indicative of specialized cellular components such as vesicles, which are involved in storage and transport functions within the cell. Their presence suggests a high level of intracellular trafficking and could be indicative of the cell's active involvement in metabolite exchange or waste removal. Moreover, the complex and densely populated cytoplasm suggests that the cell is metabolically active, possibly engaged in protein synthesis or energy production as evidenced by visible mitochondria."}],
#  'id': 'Instruction-Tuning_310784',
#  'modality': 'Microscopy Images',
#  'body_part': 'Cell'}

# %%
set([i['modality'] for i in data])
# Out:
# {'Brain',
#  'Brain Imaging',
#  'Cellularity heatmap',
#  'Chest Ultrasound',
#  'Computed Tomography',
#  'DCE MRI',
#  'Dermoscopy',
#  'Digital Photography',
#  'Endoscopy',
#  'Fundus Photography',
#  'Infrared Reflectance Imaging',
#  'Magnetic Resonance Imaging',
#  'Microscopy Images',
#  'Optical Coherence Tomography',
#  'Others',
#  'Ultrasound'}

# %%
seg_data[2]
# Out:
# {'id': 8,
#  'image': '/qumulo/shared_data/aofei_summer/data/BiomedParse/amos22/amos22/CT/train/amos_0108_73_CT_abdomen.png',
#  'conversations': [{'from': 'human',
#    'value': 'What is the modality and which organ is predominant?'},
#   {'from': 'assistant',
#    'value': 'Abdominal CT (computed tomography). The liver is the predominant organ in this slice.'},
#   {'from': 'human', 'value': 'Segment the esophagus and aorta.'},
#   {'from': 'assistant',
#    'value': 'Aorta is midline at mid-height labeled [M0_1], bbox [0.396, 0.545, 0.048, 0.046]. The esophagus is slightly right-central labeled [M0_8], bbox [0.445, 0.553, 0.032, 0.032].'},
#   {'from': 'human', 'value': 'Are the spleen and stomach visible?'},
#   {'from': 'assistant',
#    'value': 'Yes — spleen is in the left upper quadrant, stomach is just medial to the spleen; both are identified in the supplied regions.'},
#   {'from': 'human', 'value': 'Impression from these regions?'},
#   {'from': 'assistant',
# ...
